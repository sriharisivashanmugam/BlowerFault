# %% [markdown]
# <a href="https://colab.research.google.com/github/sriharisivashanmugam/BlowerFault/blob/main/Blower_Fault_v2_2_Jan_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# For every heater, regardless of period of data available, do feature engineering, normalize them temporally by period of data available and have 2 clusters faulty/non-fauly, analyze the two clusters for significant differences and try predicting new heaters in the clusters.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os

# %%
def had_fault(data):
  if 'E1.0' in set(data['ErrorCode']):
    return True
  else:
    return False

def number_of_unique_faults(data):
  data['lag_error'] = data['ErrorCode'].shift(1)
  return data[(data['ErrorCode']=='E1.0') & (data['lag_error']!='E1.0')].shape[0]

def get_stats(data):
  if had_fault(data)==True:
    data['lag'] = data['ErrorCode'].shift(1)
    end = int(data[(data['ErrorCode']=='E1.0') & (data['lag']!='E1.0')].index[0])
    data = data.iloc[0:end+1,:]
  mean_pwm = data['BlowerPWM'].mean()
  mean_rpm = data['BlowerRPM'].mean()
  mean_fr = data['FiringRate'].mean()
  mean_ft = data['FlueTemperature'].mean()
  max_pwm = data['BlowerPWM'].max()
  max_rpm = data['BlowerRPM'].max()
  max_fr = data['FiringRate'].max()
  max_ft = data['FlueTemperature'].max()

  return mean_pwm,mean_rpm,mean_fr,mean_ft,max_pwm,max_rpm,max_fr,max_ft

def get_agg(data):
  pass

# %%
new_df = {'HEX':[],'mean_pwm':[],'mean_rpm':[],'mean_fr':[],'mean_ft':[],'max_pwm':[],'max_rpm':[],'max_fr':[],'max_ft':[],'had_fault':[]}
for i in os.listdir('/content/drive/MyDrive/Predictive Models/Blower Fault Phase 2/Hex_with_blowerFault-training/Hex_with_blowerFault/'):
  temp = pd.read_csv('/content/drive/MyDrive/Predictive Models/Blower Fault Phase 2/Hex_with_blowerFault-training/Hex_with_blowerFault/'+i)
  temp = temp[['BlowerPWM','BlowerRPM','FiringRate','FlueTemperature','ErrorCode']]

  new_df['HEX'].append(i.split('.')[0])
  res = get_stats(temp)
  # print(i,had_fault(temp),number_of_unique_faults(temp),res)
  # print(i)
  new_df['mean_pwm'].append(res[0])
  new_df['mean_rpm'].append(res[1])
  new_df['mean_fr'].append(res[2])
  new_df['mean_ft'].append(res[3])
  new_df['max_pwm'].append(res[4])
  new_df['max_rpm'].append(res[5])
  new_df['max_fr'].append(res[6])
  new_df['max_ft'].append(res[7])
  new_df['had_fault'].append(had_fault(temp))

new_df = pd.DataFrame(new_df)

# %%
new_df = new_df[new_df['max_rpm']>0]

# %%
new_df.describe()
# Out:
#          mean_pwm     mean_rpm    mean_fr     mean_ft     max_pwm  \
# count   39.000000    39.000000  39.000000   39.000000   39.000000
# mean   230.640365  6206.135789  15.050409  102.146530  356.153846
# std     59.133195  1071.456876  11.485131    8.430361   30.357986
# min    113.595178  4118.827813   0.000000   83.000000  293.000000
# 25%    189.194474  5483.285174   5.940104   95.527897  345.500000
# 50%    237.119023  6162.978292  15.471253  103.184695  353.000000
# 75%    272.967454  7144.616034  20.676717  109.379103  364.500000
# max    316.604897  7788.624666  51.747328  114.187443  450.000000
#
#            max_rpm      max_fr      max_ft
# count    39.000000   39.000000   39.000000
# mean   8476.769231  197.333333  126.794872
# std     368.423916   65.698808    9.597641
# min    7597.000000    0.000000   83.000000
# 25%    8333.500000  155.000000  123.000000
# 50%    8366.000000  234.000000  127.000000
# 75%    8624.000000  251.000000  133.000000
# max    9425.000000  251.000000  142.000000

# %%
sns.pairplot(new_df,hue='had_fault')

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()

X = new_df.iloc[:,1:-1]
Y = new_df.iloc[:,-1]
X = pd.DataFrame(ss.fit_transform(X))
final_df = pd.concat([X,Y],axis=1)

# %%
sns.pairplot(final_df,hue='had_fault')

# %%
# pip install pycaret

# %%
from pycaret.classification import *
s = setup(final_df, target = 'had_fault', session_id = 124)
# Out:
# <style type="text/css">
# #T_64e6d_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_64e6d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64e6d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_64e6d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64e6d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64e6d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_64e6d_row0_col1" class="data row0 col1" >124</td>
#     </tr>
#     <tr>
#       <th id="T_64e6d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_64e6d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_64e6d_row1_col1" class="data row1 col1" >had_fault</td>
#     </tr>
#     <tr>
#       <th id="T_64e6d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_64e6d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_64e6d_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_64e6d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_64e6d_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_64e6d_row3_col1" class="data row3 col1" >(39, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_64e6d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_64e6d_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_64e6d_row4_col1" class="data row4 col1" >(39, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_64e6d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_64e6d_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_64e6d_row5_col1" class="data row5 col1" >(27, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_64e6d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_64e6d_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_64e6d_row6_col1" class="data row6 col1" >(12, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_64e6d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_64e6d_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_64e6d_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_64e6d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_64e6d_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_64e6d_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_64e6d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_64e6d_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_64e6d_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_64e6d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_64e6d_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_64e6d_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_64e6d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_64e6d_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_64e6d_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_64e6d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_64e6d_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_64e6d_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_64e6d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_64e6d_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_64e6d_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_64e6d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_64e6d_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_64e6d_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_64e6d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_64e6d_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_64e6d_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_64e6d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_64e6d_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_64e6d_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_64e6d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_64e6d_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_64e6d_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_64e6d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_64e6d_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_64e6d_row18_col1" class="data row18 col1" >443e</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models(sort='Accuracy')
# Out:
# <style type="text/css">
# #T_06b79 th {
#   text-align: left;
# }
# #T_06b79_row0_col0, #T_06b79_row0_col2, #T_06b79_row0_col3, #T_06b79_row0_col4, #T_06b79_row0_col5, #T_06b79_row0_col6, #T_06b79_row0_col7, #T_06b79_row1_col0, #T_06b79_row1_col3, #T_06b79_row1_col5, #T_06b79_row2_col0, #T_06b79_row2_col1, #T_06b79_row2_col3, #T_06b79_row2_col4, #T_06b79_row2_col5, #T_06b79_row2_col6, #T_06b79_row2_col7, #T_06b79_row3_col0, #T_06b79_row3_col1, #T_06b79_row3_col2, #T_06b79_row3_col3, #T_06b79_row3_col4, #T_06b79_row3_col5, #T_06b79_row3_col6, #T_06b79_row3_col7, #T_06b79_row4_col0, #T_06b79_row4_col1, #T_06b79_row4_col2, #T_06b79_row4_col3, #T_06b79_row4_col4, #T_06b79_row4_col5, #T_06b79_row4_col6, #T_06b79_row4_col7, #T_06b79_row5_col0, #T_06b79_row5_col1, #T_06b79_row5_col2, #T_06b79_row5_col3, #T_06b79_row5_col5, #T_06b79_row5_col6, #T_06b79_row5_col7, #T_06b79_row6_col0, #T_06b79_row6_col1, #T_06b79_row6_col2, #T_06b79_row6_col3, #T_06b79_row6_col4, #T_06b79_row6_col5, #T_06b79_row6_col6, #T_06b79_row6_col7, #T_06b79_row7_col0, #T_06b79_
row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_b4efc_row0_col5" class="data row0 col5" >0.7500</td>
#       <td id="T_b4efc_row0_col6" class="data row0 col6" >0.6364</td>
#       <td id="T_b4efc_row0_col7" class="data row0 col7" >0.6831</td>
#     </tr>
#   </tbody>
# </table>
#            0         1         2         3         4         5         6  \
# 0  -0.221699 -0.259890  0.432203  1.192423  0.795767  1.169277  0.827537
# 14 -0.373061 -0.487540 -0.062566  0.987853 -0.071876 -0.304587 -0.945757
# 12  1.385902  1.390869 -1.300003  0.815439 -0.038505 -0.389829 -1.870954
# 30 -1.156773 -0.781246 -0.967993 -1.555876 -0.939518  0.550584  0.565398
# 9   1.472748  1.496258 -1.305123  1.013623 -0.138617 -0.398079 -1.732175
# 3   0.054879 -0.206623  0.606873 -0.471425 -1.339969 -1.830697 -0.236439
# 18  1.351737  1.424824 -0.983940 -1.255245 -0.138617 -0.310087 -0.128500
# 22  0.269493  0.586276 -0.982282  0.909915 -0.338843 -0.398079 -1.639655
# 26  0.545628  0.684970  0.613624  0.155519  1.096105  0.402098  0.827537
# 37 -0.279159 -0.509006  0.279542  0.754352 -0.205359 -0.370581 -0.776138
# 38 -1.525146 -1.118563 -1.225724 -1.561690 -0.972889  0.407597  0.827537
# 4  -1.482572 -1.479518  0.920420  0.062887 -0.372214  2.607394  0.719598
#
#            7  had_fault  prediction_label  prediction_score
# 0   0.549424      False                 0              0.91
# 14 -0.295011       True                 0              0.78
# 12 -1.033891      False                 0              0.70
# 30  0.338315       True                 1              0.67
# 9  -0.822782      False                 0              0.76
# 3  -0.611674      False                 0              0.80
# 18 -0.189456       True                 1              0.62
# 22 -0.822782      False                 0              0.74
# 26  0.654978      False                 0              0.87
# 37  0.443869      False                 0              0.55
# 38  0.338315       True                 1              0.69
# 4   1.604967       True                 0              0.56

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# Testing the model

# %%
test_df = {'HEX':[],'mean_pwm':[],'mean_rpm':[],'mean_fr':[],'mean_ft':[],'max_pwm':[],'max_rpm':[],'max_fr':[],'max_ft':[],'had_fault':[]}
for i in os.listdir('/content/drive/MyDrive/Predictive Models/Blower Fault Phase 2/Hex_with_blowerFault/'):
  temp = pd.read_csv('/content/drive/MyDrive/Predictive Models/Blower Fault Phase 2/Hex_with_blowerFault/'+i)
  temp = temp[['BlowerPWM','BlowerRPM','FiringRate','FlueTemperature','ErrorCode']]

  test_df['HEX'].append(i.split('.')[0])
  res = get_stats(temp)
  print(i)
  # print(i,had_fault(temp),number_of_unique_faults(temp),res)
  test_df['mean_pwm'].append(res[0])
  test_df['mean_rpm'].append(res[1])
  test_df['mean_fr'].append(res[2])
  test_df['mean_ft'].append(res[3])
  test_df['max_pwm'].append(res[4])
  test_df['max_rpm'].append(res[5])
  test_df['max_fr'].append(res[6])
  test_df['max_ft'].append(res[7])
  test_df['had_fault'].append(had_fault(temp))

test_df = pd.DataFrame(test_df)
# Out:
# iQ100110241866_HEX_1.csv
# iQ100110241866_HEX_2.csv
# iQ100110241866_HEX_3.csv
# iQ100110241866_HEX_4.csv
# iQ100101021861_HEX_1.csv
# iQ100101021861_HEX_2.csv
# iQ100101021861_HEX_3.csv
# iQ100101021861_HEX_4.csv
# iQ100101081865_HEX_1.csv
# iQ100101081865_HEX_2.csv
# iQ100101081865_HEX_3.csv
# iQ100104291976_HEX_1.csv
# iQ100112161907_HEX_3.csv
# iQ100108271948_HEX_3.csv
# iQ100110181750_HEX_1.csv
# iQ100110121749_HEX_1.csv
# iQ100108301830_HEX_1.csv
# iQ100110121749_HEX_2.csv
# iQ100108301830_HEX_3.csv
# iQ100102281891_HEX_2.csv
# iQ100108281950_HEX_3.csv
# iQ100105012068_HEX_3.csv
# iQ100104272063_HEX_1.csv
# iQ100102062041_HEX_3.csv
# iQ100105012068_HEX_1.csv
# iQ100108301830_HEX_4.csv
# iQ100108281950_HEX_2.csv
# iQ100105182075_HEX_4.csv
# iQ100108281950_HEX_1.csv
# iQ100111162132_HEX_3.csv
# iQ100108271948_HEX_2.csv
# iQ100110121749_HEX_4.csv
# iQ150108141833_HEX_1.csv
# iQ100104041806_HEX_4.csv
# iQ150108141833_HEX_4.csv
# iQ100110301873_HEX_4.csv
# iQ100108271948_HEX_1.csv
# iQ150108141833_HEX_2.csv
# iQ100110301873_HEX_1.csv
# iQ100105142074_HEX_3.csv
# iQ100110301875_HEX_4.csv

# %%
test_df = test_df[~test_df['HEX'].isin(new_df['HEX'])]

# %%
x = test_df.iloc[:,1:-1]
y = test_df.iloc[:,-1]

x = pd.DataFrame(ss.transform(x))

test_df = pd.concat([x,y],axis=1)

# %%
test_df.dropna(inplace=True)

# %%
predictions = predict_model(best, data=test_df, raw_score=True)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_61a75" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61a75_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_61a75_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_61a75_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_61a75_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_61a75_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_61a75_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_61a75_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_61a75_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61a75_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_61a75_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_61a75_row0_col1" class="data row0 col1" >0.5333</td>
#       <td id="T_61a75_row0_col2" class="data row0 col2" >0.4070</td>
#       <td id="T_61a75_row0_col3" class="data row0 col3" >0.5333</td>
#       <td id="T_61a75_row0_col4" class="data row0 col4" >0.5222</td>
#       <td id="T_61a75_row0_col5" class="data row0 col5" >0.5212</td>
#       <td id="T_61a75_row0_col6" class="data row0 col6" >0.0308</td>
#       <td id="T_61a75_row0_col7" class="data row0 col7" >0.0316</td>
#     </tr>
#   </tbody>
# </table>
#            0         1          2         3         4         5         6  \
# 0  -1.392267 -1.641630   0.270860 -1.091626  3.131728  2.304922  0.827537
# 1  -1.408513 -1.801246   1.019388 -1.787134  3.131728  1.963954  0.873797
# 3   0.904068  0.815001   0.443098  0.629906  0.361946 -0.370581  0.827537
# 16 -0.649275 -0.351353  10.656642  3.485206  2.464311  3.286582  0.827537
# 20 -0.965621 -0.720517  -0.199940  0.553747  1.096105  1.251769  0.580818
#
#            7 had_fault  prediction_label  prediction_score_0  \
# 0   1.604967     False                 0                0.60
# 1   0.232761      True                 1                0.32
# 3   1.816076      True                 0                0.81
# 16  2.238293      True                 0                0.76
# 20  0.338315      True                 0                0.82
#
#     prediction_score_1
# 0                 0.40
# 1                 0.68
# 3                 0.19
# 16                0.24
# 20                0.18

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(predictions['had_fault'],predictions['prediction_label']))
# Out:
# [[17  8]
#  [13  7]]
